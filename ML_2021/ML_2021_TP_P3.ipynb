# %% [markdown]
# # 코드 시작 전 설명
# 1. 음성 데이터에 대한 이론 및 과정을 잘 모르시는 분은 코드를 작성하기 전 overview를 한번 정독하시는 것을 권합니다.
#
# 2. 스켈레톤 코드가 적혀있는 해당 ipynb 파일을 다운받아 자신의 작업공간(코랩, 캐글노트북 등등)에서 코드를 작성합니다.
#
# 3. 각 코드에는 빈칸과 함께 구현 가이드 라인이 제공됩니다. 해당 가이드라인을 따라 코드를 작성하여 베이스 라인 성능을 달성합니다.
#    진행에 어려움이 있으신 경우에는 feature 가공에 사용되는 함수의 documentation 설명을 읽으시는 것을 권합니다.
#
# 4. (선택)베이스라인에 도달하였다면, 음성 feature를 새롭게 가공하여 추가적인 성능 향상을 달성해봅니다.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/2021-ml-tp-p6/train_data.csv
# /kaggle/input/2021-ml-tp-p6/test_data.csv
# /kaggle/input/2021-ml-tp-p6/sample_submit.csv
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_132.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_185.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_268.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_344.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_093.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_131.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_327.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_120.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_064.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_371.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_028.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_250.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_408.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_334.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_258.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_129.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_218.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_142.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_198.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_125.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_037.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_007.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_066.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_112.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_335.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_252.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_322.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_152.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_149.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_153.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_320.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_377.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_227.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_019.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_158.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_084.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_318.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_035.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_302.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_214.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_016.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_221.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_284.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_237.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_405.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_039.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_372.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_400.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_311.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_026.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_428.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_395.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_077.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_261.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_230.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_202.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_272.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_057.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_068.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_404.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_370.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_113.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_283.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_313.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_217.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_396.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_219.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_045.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_005.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_365.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_431.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_271.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_054.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_107.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_117.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_324.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_150.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_248.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_286.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_180.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_288.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_414.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_278.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_415.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_033.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_346.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_222.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_331.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_247.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_289.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_209.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_220.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_342.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_083.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_216.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_173.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_133.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_358.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_021.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_423.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_020.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_225.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_416.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_061.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_034.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_279.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_360.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_231.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_163.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_354.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_411.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_208.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_285.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_401.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_130.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_036.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_143.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_210.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_100.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_234.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_292.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_009.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_146.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_387.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_380.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_168.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_052.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_075.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_430.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_055.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_413.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_147.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_200.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_274.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_240.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_426.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_315.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_397.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_307.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_236.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_080.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_304.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_105.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_065.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_349.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_422.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_417.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_267.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_193.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_266.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_014.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_104.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_348.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_276.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_172.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_156.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_050.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_154.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_337.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_040.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_103.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_224.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_201.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_119.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_379.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_047.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_108.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_062.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_226.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_140.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_114.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_253.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_296.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_191.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_043.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_188.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_196.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_159.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_116.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_329.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_030.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_306.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_339.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_376.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_352.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_161.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_137.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_362.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_343.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_031.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_058.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_155.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_186.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_022.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_375.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_148.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_340.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_277.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_336.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_187.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_392.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_095.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_069.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_319.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_029.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_046.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_323.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_244.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_124.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_086.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_297.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_178.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_420.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_012.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_427.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_310.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_194.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_203.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_382.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_301.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_338.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_390.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_369.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_256.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_368.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_189.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_374.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_232.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_171.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_332.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_004.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_003.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_032.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_233.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_273.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_110.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_044.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_263.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_386.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_429.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_239.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_144.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_184.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_246.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_238.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_092.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_070.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_136.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_177.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_293.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_001.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_141.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_378.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_002.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_121.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_102.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_241.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_245.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_366.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_350.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_135.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_235.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_056.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_127.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_051.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_356.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_164.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_122.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_399.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_394.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_355.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_042.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_088.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_183.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_098.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_182.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_316.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_211.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test_078.wav
# /kaggle/input/2021-ml-tp-p6/test_data/test_data/test
test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1008 entries, 0 to 1007
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1008 non-null   int64
#  1   file_name  1008 non-null   object
#  2   emotion    1008 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 23.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         432 non-null    int64
#  1   file_name  432 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 6.9+ KB
# None None

# %%
pd_train
# Out:
#         ID       file_name    emotion
# 0        0   train_000.wav    disgust
# 1        1   train_001.wav  surprised
# 2        2   train_002.wav    disgust
# 3        3   train_003.wav       calm
# 4        4   train_004.wav    neutral
# ...    ...             ...        ...
# 1003  1003  train_1003.wav       calm
# 1004  1004  train_1004.wav    disgust
# 1005  1005  train_1005.wav       calm
# 1006  1006  train_1006.wav    fearful
# 1007  1007  train_1007.wav    neutral
#
# [1008 rows x 3 columns]

# %%
pd_test
# Out:
#       ID     file_name
# 0      0  test_000.wav
# 1      1  test_001.wav
# 2      2  test_002.wav
# 3      3  test_003.wav
# 4      4  test_004.wav
# ..   ...           ...
# 427  427  test_427.wav
# 428  428  test_428.wav
# 429  429  test_429.wav
# 430  430  test_430.wav
# 431  431  test_431.wav
#
# [432 rows x 2 columns]

# %% [markdown]
# # **Feature 추출**
#
# * extract_feature 함수는 음성 데이터를 읽어서 다음의 과정들을 거치며 feature를 추출합니다.(함수(입력) --> 출력)
#  1. Sampling&Quantization(continuos audio signal) --> Discrete audio signal
#  2. Short Time Fourier Transfrom(Discrete audio signal) --> Spectrogram
#  3. Mel-Filter(Spectrogram) --> Mel-Spectrogram
#  4. Discrete Cosine Transform(Mel-Spectrogram) --> Mel Frequency Cepstrum Coefficient
#
# 위에 과정들은 모두 librosa 라이브러리에서 제공하는 함수들을 통하여 구현가능하며 사용되는 함수는 다음과 같습니다.
#
# 1. librosa.load : Continuos audio signal(.wav파일)을 Discrete audio signal로 읽음.
# 2. librosa.stft : Discrte audio signal을 windowing하여 프레임별로 나눈 후 FFT(Fast Fourier Transform)을 수행
# [stft_documentation](https://librosa.org/doc/latest/generated/librosa.stft.html?highlight=stft)
# 3. librosa.feature.melspectrogram : stft 함수를 통하여 구한 spectrogram을 입력으로 Mel-filter를 적용함으로써 Mel-Spectrogram 생성[melspectrogram_documentation](https://librosa.org/doc/latest/generated/librosa.feature.melspectrogram.html?highlight=melspectrogram)
# 4. librosa.feature.mfcc : melspectrogram 함수를 통하여 구한 Mel-spectrogram을 입력으로 DCT를 수행함으로써 MFCC를 생성 [mfcc_documentation](https://librosa.org/doc/latest/generated/librosa.feature.mfcc.html?highlight=mfcc)

# %%
import librosa
import glob, pickle
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import librosa, librosa.display

# %%
file_name = '/kaggle/input/2021-ml-tp-p6/train_data/train_data/train_920.wav'
X, sample_rate = librosa.load(file_name, sr=22050)
spectrogram = np.abs(librosa.stft(X,  n_fft = 512))
spectrogram_feature =np.mean(spectrogram, axis = 1)

# %%
spectrogram_feature.shape
# Out:
# (257,)

# %%
spectrogram.shape
# Out:
# (257, 673)

# %%
power_spectrogram = spectrogram**2

# %%
power_spectrogram
# Out:
# array([[0.0000000e+00, 0.0000000e+00, 2.0058965e-12, ..., 6.8318462e-07,
#         1.9985589e-07, 8.2298222e-08],
#        [0.0000000e+00, 0.0000000e+00, 1.9959754e-12, ..., 7.0704118e-07,
#         4.3876616e-07, 5.5789439e-08],
#        [0.0000000e+00, 0.0000000e+00, 1.9665226e-12, ..., 7.6742612e-07,
#         4.4681718e-07, 8.8144487e-09],
#        ...,
#        [0.0000000e+00, 0.0000000e+00, 2.5820354e-20, ..., 2.6809425e-23,
#         1.2635431e-16, 4.2949653e-15],
#        [0.0000000e+00, 0.0000000e+00, 2.5777150e-20, ..., 2.6815282e-23,
#         1.2619331e-16, 4.2882690e-15],
#        [0.0000000e+00, 0.0000000e+00, 2.5783493e-20, ..., 9.6808537e-23,
#         1.2638160e-16, 4.2857140e-15]], dtype=float32)

# %%
import librosa
import glob, pickle
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import librosa, librosa.display 


# -------------------------------------
# extract_feature(file_name): <= 코드를 추가하여 음성 feature를 추출하는 코드를 완성하세요
# -------------------------------------
# 목적: MFCC를 비롯한 여러 음성 feature를 추출
# 입력인자: .wav 음성 파일의 이름
# 출력인자: 입력 파일을 가공한 feature들 (Spectrogram, Mel-spectrogram, MFCC)
# -------------------------------------


def extract_feature(file_name):
    
    
    result=np.array([])
    X, sample_rate = librosa.load(file_name, sr=22050)
    #----------step3. spectrogram을 구하세요.---------------------
    # 구현 가이드 라인(3)
    # ------------------------------------------------------------------------------
    # 1. 입력 신호(X)를 librosa.stft 함수의 입력으로 하여 spectrogram을 구하세요.
    #   -참고) 사람의 음성은 20~40(ms) 사이 시간 내에서 현재 말하는 발음을 변경할 수 없다고 합니다.
    #       시간축에 대한 구간을 나눌 때 20~40(ms) 이내 간격으로 나누기 위하여 n_fft 파라미터 값을 조정해주세요.(베이스라인 성능은 23ms 간격으로 나누었습니다.)
    #       정확한 조정을 위하여 librosa documentation에서 librosa.stft 함수 내 n_fft 파라미터 설명을 참조하세요.
    #
    # 2. spectrogram에 절대값을 취하여 복소수 형태의 값을 바꾸세요.
    #
    # 3. 구한 spectrogram을 학습에 사용하기 위하여 프레임 축의 평균값을 취한 뒤 spectrogram_feature에 저장해주세요
    #   -참고) spectrogram의 shape은 (frequency의 길이, 프레임 수)로 이루어져있습니다.
    #       (np.mean함수를 사용하여 spectrogram의 shape이 (1, frequency의 길이)가 되면 성공.)
    # -----------------------------------------------------------------------------
    
    #-------------------------------------------------------------------------------
    spectrogram = np.abs(librosa.stft(X,  n_fft = 512))
    spectrogram_feature = np.mean(spectrogram, axis = 1)
#     print(spectrogram_feature.shape)
    #-------------------------------------------------------------------------------
    
    #----------step4. Mel-spectrogram을 구하세요.---------------------
    # 구현 가이드 라인(4)
    # ------------------------------------------------------------------------------
    # 1. step3-2에서 구한 spectrogram을 제곱하여 power spectrogram을 만드세요.
    #
    # 2. power spectrogram을 librosa.feature.melspectrogram 함수의 입력으로 하여 mel-spectrogram을 구하세요.
    #   - 참고) documentation을 통해 librosa.feature.melspectrogram 함수의 입력 인자를 꼭 확인하셔서 올바르게 넣어주세요.
    #
    # 3. step4-2에서 구한 mel-spectrogram은 power-magnitude 값입니다. librosa.power_to_db함수를 통하여 power magnitude를 데쉬벨(db)로 변환하세요.
    #
    # 4. 구한 mel-spectrogram을 학습에 사용하기 위하여 프레임 축의 평균값을 취한 뒤 mel_spectrogram_feature에 저장해주세요
    #   -참고) mel-spectrogram의 shape은 (mel filter의 길이, 프레임 수)로 이루어져있습니다.
    #       (np.mean함수를 사용하여 mel-spectrogram의 shape이 (1, mel filter의 길이)가 되면 성공.)
    # -----------------------------------------------------------------------------

    
    power_spectrogram = spectrogram**2
    mel_spectrogram = librosa.feature.melspectrogram(S = power_spectrogram, sr = sample_rate)
    power_magnitude = librosa.power_to_db(mel_spectrogram, ref = np.max)
    
    #-------------------------------------------------------------------
    mel_spectrogram_feature= np.mean(power_magnitude, axis = 1)
#     print(mel_spectrogram.shape)
#     print(mel_spectrogram_feature.shape)
    #-------------------------------------------------------------------------------

    
    #----------step5. MFCC를 구하세요.---------------------
    # 구현 가이드 라인(5)
    # ------------------------------------------------------------------------------ 
    # 1. step4-3에서 데쉬벨로 변환한 mel-spectrogram을 librosa.feature.mfcc 함수의 입력으로 하여 MFCC를 구하세요.
    #   - 참고) documentation을 통해 librosa.feature.mfcc 함수의 입력 인자를 꼭 확인하셔서 올바르게 넣어주세요.
    #
    # 2. 구한 MFCC 학습에 사용하기 위하여 프레임 축의 평균값을 취한 뒤 mfcc_feature에 저장해주세요
    # -참고) MFCC shape은 (MFCC의 길이, 프레임 수)로 이루어져있습니다.
    #       (np.mean함수를 사용하여 MFCC의 shape이 (1, MFCC의 길이)가 되면 성공.)
    # -----------------------------------------------------------------------------
    
    mfcc_feature = np.mean(librosa.feature.mfcc(S=power_magnitude, sr = sample_rate), axis = 1)
    #-------------------------------------------------------------------------------

    return spectrogram_feature, mel_spectrogram_feature, mfcc_feature

# %% [markdown]
# # **데이터 불러오기**
#
# ### csv파일에 저장된 파일 이름과 학습용 label을 로드하여 학습 및 평가용 데이터를 불러오세요.

# %%
# '/kaggle/input/2021-ml-tp-p6/train_data/train_data/train_920.wav'

# %%
# PATH = join('/kaggle','input','2021-ml-tp-p6')
# PATH

# %%
# print(pd_train['file_name'][0])
# print(pd_train['emotion'][0])

# %%
# zip(pd_train['file_name'], pd_train['emotion'])

# %%
# from tqdm import tqdm
# # for file_name, emotion in tqdm(zip(pd_train['file_name'], pd_train['emotion'])):
# #     print(file_name, emotion)

# %%
# path = join(PATH,'train_data','train_data',pd_train['file_name'][0])
# path

# %%
#DataFlair - Load the data and extract features for each sound file
from tqdm import tqdm
def load_data(data_info, isTrain=True):
    
    PATH = join('/kaggle','input','2021-ml-tp-p6')
    if isTrain:
        train_data = {'spectrogram':[],'mel':[],'mfcc':[]}#음성 feature들을 담는 dictionary
        train_label = []#학습에 사용할 label을 담는 list
        
        file_list = data_info['file_name']
        emotion_list = data_info['emotion']
        for file_name, emotion in tqdm(zip(file_list, emotion_list)):
            # ------------- step1. 학습용 데이터로더 코드를 작성하세요.----------------------
            # 구현 가이드라인  (1)
            # ------------------------------------------------------------
            # train.csv 파일에 있는 음성 파일의 이름과 emotion 정보를 통하여 학습용 데이터를 로드하세요.
            # 음성 파일의 정확한 경로 명을 extract_feature 함수의 입력으로 넣을 수 있게 경로를 잘 설정해보세요.
            # extract_feature를 통해 구한 음성 feature들을 train_data 사전 속 배열에 알맞게 append 해주세요. ex) train_data['spectrogram'].append(spectrogram_feature)
            # ------------------------------------------------------------
            # 구현 가이드라인을 참고하여 코드를 작성해보세요.
            
            file_path = join(PATH,'train_data','train_data',file_name)
            spectrogram_feature, mel_spectrogram_feature, mfcc_feature  = extract_feature(file_path)
            train_data['spectrogram'].append(spectrogram_feature)
            train_data['mel'].append(mel_spectrogram_feature)
            train_data['mfcc'].append(mfcc_feature)
            
            train_label.append(emotion)
            #----------------------------------------------------------------------------------------- 
            
        return train_data, np.array(train_label)
    
    else:
        test_data = {'spectrogram':[],'mel':[],'mfcc':[]}#음성 feature들을 담는 dictionary
        file_list = data_info['file_name']
    
        for file_name in tqdm(file_list):
            # -------------step2. 평가용 데이터로더 코드를 작성하세요.-----------------
            # 구현 가이드라인  (2)
            # ------------------------------------------------------------
            # test.csv 파일에 있는 음성 파일의 이름정보를 통하여 평가용 데이터를 로드하세요.
            # 음성 파일의 정확한 경로 명을 extract_feature 함수의 입력으로 넣을 수 있게 경로를 잘 설정해보세요.
            # extract_feature를 통해 구한 음성 feature들을 test_data 사전 속 배열에 알맞게 append 해주세요. ex) test_data['spectrogram'].append(spectrogram_feature)
            # ------------------------------------------------------------
            # 구현 가이드라인을 참고하여 코드를 작성해보세요.
            
            file_path = join(PATH,'test_data','test_data',file_name)
            spectrogram_feature, mel_spectrogram_feature, mfcc_feature  = extract_feature(file_path)
            test_data['spectrogram'].append(spectrogram_feature)
            test_data['mel'].append(mel_spectrogram_feature)
            test_data['mfcc'].append(mfcc_feature)
            
            #----------------------------------------------------------------------------------------- 
            
        return test_data

#DataFlair - Split the dataset
train_data, y_train = load_data(pd_train)
test_data = load_data(pd_test, isTrain=False)
# Out:
# 1008it [02:36,  6.43it/s]
# 100%|██████████| 432/432 [01:06<00:00,  6.45it/s]

# %% [markdown]
# # 모델 학습 및 추론
# 위에서 우리는
# 1. 음성 신호에 대하여 Short Time Fourier Transform(stft)를 통해 **spectrogram**을 구하고,
# 2. 구한 spectrogram에 mel-filter를 씌워 **mel-spectrogram**을 구했으며,
# 3. 마지막으로 mel-spectrogram에 Discrete cosine transform(DCT) 취해줌으로써 **mfcc**까지 계산하였습니다.
#
# 위에서 구한 feature들은 모두 음성 데이터를 활용하는 다양한 작업(사람 음성 분류, 음성을 통한 감정 분류 등)에서 모델 학습에 사용할 수 있는 feature들입니다.
# 각각의 **feature들에 따른 모델의 정확도가 얼마나 차이**나는지를 확인해봅시다.
#
# - 베이스라인의 분류기는 **RandomForestClassifier**를 사용합니다.
# - **random_state에 따른 성능 차이가 발생하오니 반드시 random_state를 1로 고정해주시길 바랍니다.**

# %%
#RandomForestClassifier로 음성 감정 분류 학습 및 평가
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

sample = pd.read_csv(join(DATA_PATH,'sample_submit.csv'))

from sklearn.model_selection import GridSearchCV

for feature_name in train_data.keys():
    # ------------- step6. 음성 feature들을 가지고 모델을 학습하세요.----------------------
    # 구현 가이드라인  (6)
    # ------------------------------------------------------------
    # dictionary 형태의 train_data 변수 내에는 spectrogram, mel-spectrogram, mfcc feature들이 존재합니다.
    # 반복문을 통해 각 종류의 feature를 하나씩 불러오세요. ex) x_train = np.array(train_data[feature_name])
    # 불러온 feature로 모델을 학습 및 추론 후 sample submit파일에 저장하세요.
    # ------------------------------------------------------------
    # 구현 가이드라인을 참고하여 코드를 작성해보세요.
    sc = StandardScaler()
    
    rfc = RandomForestClassifier(max_depth=2, random_state=1)
    param_grid = {"n_estimators":[100, 300, 500, 700], 'max_depth':[10, 11, 12, 13, 14, 15], 'criterion':['gini', 'entropy']}
    clf = GridSearchCV(rfc, param_grid)

    x_train = np.array(train_data[feature_name])
    x_train_std = sc.fit_transform(x_train)
    
    clf.fit(x_train_std, y_train)
    
    model = clf.best_estimator_

    
    x_test = np.array(test_data[feature_name])
    x_test_std = sc.transform(x_test)
    

    predict = model.predict(x_test_std)
      
    
    
    #-------------------------------------------------------------------------------------------
    #Sample submit file 저장
    sample['emotion'] = predict.reshape(-1,1)
    sample.to_csv(join(feature_name+'.csv'),index=False,header=True)

#만약 코랩사용시 사용
# !kaggle competitions submit -c 2021-ml-tp-p6 -f spectrogram.csv -m "spectrogram"
# !kaggle competitions submit -c 2021-ml-tp-p6 -f mel.csv -m "mel-spectrogram"
# !kaggle competitions submit -c 2021-ml-tp-p6 -f mfcc.csv -m "mfcc"

# %%
predict
# Out:
# array(['surprised', 'calm', 'disgust', 'calm', 'disgust', 'sad',
#        'disgust', 'disgust', 'happy', 'sad', 'fearful', 'angry',
#        'surprised', 'surprised', 'surprised', 'surprised', 'disgust',
#        'calm', 'happy', 'calm', 'angry', 'surprised', 'happy', 'calm',
#        'fearful', 'happy', 'disgust', 'surprised', 'calm', 'neutral',
#        'sad', 'disgust', 'calm', 'sad', 'disgust', 'fearful', 'calm',
#        'happy', 'disgust', 'sad', 'fearful', 'surprised', 'neutral',
#        'angry', 'fearful', 'angry', 'neutral', 'sad', 'surprised',
#        'neutral', 'surprised', 'happy', 'fearful', 'disgust', 'happy',
#        'calm', 'fearful', 'disgust', 'surprised', 'calm', 'angry',
#        'surprised', 'surprised', 'surprised', 'sad', 'disgust',
#        'surprised', 'disgust', 'fearful', 'calm', 'sad', 'fearful',
#        'angry', 'surprised', 'neutral', 'calm', 'calm', 'happy', 'sad',
#        'fearful', 'sad', 'calm', 'disgust', 'calm', 'surprised', 'happy',
#        'angry', 'disgust', 'disgust', 'disgust', 'disgust', 'sad',
#        'angry', 'neutral', 'fearful', 'neutral', 'fearful', 'happy',
#        'calm', 'fearful', 'calm', 'calm', 'disgust', 'neutral', 'sad',
#        'angry', 'calm', 'surprised', 'surprised', 'happy', 'surprised',
#        'calm', 'sad', 'surprised', 'happy', 'surprised', 'surprised',
#        'sad', 'disgust', 'calm', 'angry', 'calm', 'sad', 'fearful',
#        'fearful', 'calm', 'angry', 'disgust', 'disgust', 'surprised',
#        'sad', 'happy', 'calm', 'surprised', 'sad', 'calm', 'happy', 'sad',
#        'sad', 'happy', 'disgust', 'disgust', 'calm', 'calm', 'happy',
#        'disgust', 'disgust', 'happy', 'calm', 'surprised', 'happy',
#        'disgust', 'disgust', 'happy', 'sad', 'calm', 'calm', 'calm',
#        'surprised', 'surprised', 'sad', 'fearful', 'disgust', 'neutral',
#        'disgust', 'calm', 'sad', 'fearful', 'fearful', 'angry', 'angry',
#        'surprised', 'disgust', 'calm', 'surprised', 'angry', 'angry',
#        'fearful', 'disgust', 'angry', 'calm', 'sad', 'calm', 'disgust',
#        'surprised', 'fearful', 'fearful', 'disgust', 'calm', 'disgust',
#        'disgust', 'calm', 'happy', 'surprised', 'angry', 'happy',
#        'surprised', 'disgust', 'angry', 'disgust', 'angry', 'disgust',
#        'calm', 'disgust', 'calm', 'surprised', 'disgust', 'angry',
#        'angry', 'sad', 'calm', 'happy', 'disgust', 'happy', 'surprised',
#        'calm', 'surprised', 'angry', 'disgust', 'angry', 'neutral',
#        'disgust', 'disgust', 'happy', 'fearful', 'disgust', 'happy',
#        'calm', 'angry', 'fearful', 'fearful', 'fearful', 'calm',
#        'neutral', 'calm', 'angry', 'disgust', 'fearful', 'surprised',
#        'fearful', 'calm', 'disgust', 'sad', 'calm', 'sad', 'disgust',
#        'surprised', 'sad', 'angry', 'sad', 'neutral', 'sad', 'angry',
#        'surprised', 'angry', 'fearful', 'angry', 'disgust', 'calm',
#        'surprised', 'angry', 'calm', 'disgust', 'disgust', 'angry',
#        'neutral', 'calm', 'happy', 'surprised', 'sad', 'happy', 'happy',
#        'happy', 'calm', 'sad', 'disgust', 'disgust', 'angry', 'fearful',
#        'calm', 'angry', 'surprised', 'fearful', 'surprised', 'disgust',
#        'surprised', 'calm', 'calm', 'angry', 'happy', 'sad', 'calm',
#        'disgust', 'surprised', 'surprised', 'angry', 'calm', 'disgust',
#        'fearful', 'calm', 'fearful', 'happy', 'calm', 'surprised',
#        'angry', 'disgust', 'calm', 'fearful', 'calm', 'disgust', 'sad',
#        'angry', 'sad', 'disgust', 'disgust', 'calm', 'happy', 'sad',
#        'surprised', 'surprised', 'sad', 'surprised', 'calm', 'angry',
#        'calm', 'angry', 'fearful', 'neutral', 'surprised', 'disgust',
#        'calm', 'surprised', 'calm', 'surprised', 'disgust', 'neutral',
#        'angry', 'happy', 'sad', 'disgust', 'disgust', 'fearful', 'sad',
#        'surprised', 'surprised', 'surprised', 'sad', 'disgust', 'calm',
#        'sad', 'neutral', 'surprised', 'disgust', 'angry', 'happy', 'calm',
#        'fearful', 'disgust', 'happy', 'disgust', 'fearful', 'disgust',
#        'surprised', 'angry', 'calm', 'neutral', 'surprised', 'calm',
#        'calm', 'disgust', 'disgust', 'surprised', 'neutral', 'calm',
#        'sad', 'angry', 'disgust', 'angry', 'sad', 'sad', 'fearful',
#        'calm', 'happy', 'angry', 'happy', 'sad', 'sad', 'calm',
#        'surprised', 'angry', 'fearful', 'sad', 'calm', 'angry', 'fearful',
#        'calm', 'disgust', 'surprised', 'angry', 'disgust', 'sad',
#        'disgust', 'neutral', 'calm', 'sad', 'calm', 'disgust', 'calm',
#        'calm', 'calm', 'disgust', 'happy', 'fearful', 'surprised',
#        'neutral', 'disgust', 'surprised', 'sad', 'angry', 'disgust',
#        'calm', 'surprised', 'happy', 'disgust', 'fearful', 'calm',
#        'happy', 'calm', 'happy', 'happy', 'calm', 'sad'], dtype='<U9')
